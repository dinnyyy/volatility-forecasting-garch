# %% [markdown]
# ## Step 1: Download raw data

# %%
import yfinance as yf
import pandas as pd

# Example: Download daily S&P 500 data
ticker = "^GSPC"  # S&P 500 index
data = yf.download(ticker, start="2015-01-01", end="2024-12-31")

# Keep only adjusted closing prices
data = data[['Close']].rename(columns={'Close': 'price'})
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ## Step 2: Calculate returns

# %%
import numpy as np

data['log_return'] = np.log(data['price'] / data['price'].shift(1))
data.dropna(inplace=True)

# %% [markdown]
# ## Step 3: Check for missing values or duplicates

# %%
data = data.dropna()
data = data[~data.index.duplicated()]

# %% [markdown]
# ## Step 4: Save as cleaned data

# %%
data.to_csv("../data/cleaned_data.csv")

# %%
print(data)
# Out:
# Price             price log_return
# Ticker            ^GSPC
# Date
# 2015-01-05  2020.579956  -0.018447
# 2015-01-06  2002.609985  -0.008933
# 2015-01-07  2025.900024   0.011563
# 2015-01-08  2062.139893   0.017730
# 2015-01-09  2044.810059  -0.008439
# ...                 ...        ...
# 2024-12-23  5974.069824   0.007261
# 2024-12-24  6040.040039   0.010982
# 2024-12-26  6037.589844  -0.000406
# 2024-12-27  5970.839844  -0.011117
# 2024-12-30  5906.939941  -0.010760
#
# [2514 rows x 2 columns]
